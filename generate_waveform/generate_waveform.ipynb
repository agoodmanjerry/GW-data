# %%
from pycbc.waveform import get_td_waveform
from pycbc.detector import Detector

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
csv_path = "/home/chiajui.chou/MDC-DeepClean/pe_check/pe_analysis.csv"
injections = pd.read_csv(csv_path)

# %%
injections
# Out:
#       approximant  coa_phase       dec     distance  f_lower  f_ref  \
# 0    IMRPhenomPv2   1.465511  0.965048  1602.554591     10.0   10.0
# 1    IMRPhenomPv2   0.781224 -0.750071  1437.108496     10.0   10.0
# 2    IMRPhenomPv2   3.585962 -0.848215  3974.303226     10.0   10.0
# 3    IMRPhenomPv2   0.069477  0.351303  1620.849279     10.0   10.0
# 4    IMRPhenomPv2   3.611868 -0.687979  2073.413260     10.0   10.0
# ..            ...        ...       ...          ...      ...    ...
# 253  IMRPhenomPv2   2.188447 -0.252950  3943.879831     10.0   10.0
# 254  IMRPhenomPv2   2.162770 -0.089497  1148.211815     10.0   10.0
# 255  IMRPhenomPv2   5.458007  0.276832  1428.640015     10.0   10.0
# 256  IMRPhenomPv2   0.468490 -0.662326  2915.516849     10.0   10.0
# 257  IMRPhenomPv2   1.943066 -0.845071  1935.224507     10.0   10.0
#
#      inclination  lambda1  lambda2      mass1  ...        ra    spin1x  \
# 0       0.831753      0.0      0.0  41.902332  ...  3.477388 -0.759538
# 1       0.509237      0.0      0.0  33.410473  ...  1.224506  0.191341
# 2       2.640085      0.0      0.0  38.664645  ...  5.029076 -0.106299
# 3       2.251201      0.0      0.0  35.620294  ...  4.322775  0.085808
# 4       2.343262      0.0      0.0  46.037080  ...  1.605076  0.014437
# ..           ...      ...      ...        ...  ...       ...       ...
# 253     0.405718      0.0      0.0  36.142558  ...  3.967550 -0.238952
# 254     0.996230      0.0      0.0  35.479052  ...  0.798278 -0.197206
# 255     2.287595      0.0      0.0  37.579371  ...  3.132361  0.030591
# 256     2.752722      0.0      0.0  41.149563  ...  0.372082  0.164047
# 257     2.304772      0.0      0.0  37.995184  ...  1.351534 -0.395255
#
#        spin1y    spin1z    spin2x    spin2y    spin2z            tc  \
# 0   -0.420117 -0.458792  0.285364 -0.351638 -0.258373  1.251335e+09
# 1   -0.517821 -0.370329  0.438609 -0.008250  0.458751  1.251337e+09
# 2    0.037143  0.017154 -0.580927  0.561362  0.378641  1.251337e+09
# 3    0.107254  0.068681 -0.560088 -0.021618 -0.498484  1.251338e+09
# 4    0.597387 -0.165187  0.105061  0.034377 -0.014738  1.251340e+09
# ..        ...       ...       ...       ...       ...           ...
# 253 -0.496907  0.080426  0.222007 -0.308360  0.614463  1.253024e+09
# 254 -0.328284 -0.207152 -0.342059 -0.708488 -0.226806  1.253056e+09
# 255 -0.001805 -0.008947  0.005767 -0.013399  0.010433  1.253056e+09
# 256  0.158479  0.108540 -0.079931 -0.341587  0.080770  1.253058e+09
# 257 -0.068064  0.001472 -0.010691  0.003700  0.012207  1.253058e+09
#
#      event_label      f_lso
# 0             50  60.828677
# 1             76  69.354319
# 2             81  60.657018
# 3            101  69.200796
# 4            122  64.892637
# ..           ...        ...
# 253        24494  68.537462
# 254        24947  62.565206
# 255        24954  60.240154
# 256        24980  56.116462
# 257        24983  69.252268
#
# [258 rows x 22 columns]

# %%
fs = 4096
hp, hc = get_td_waveform(
    approximant='IMRPhenomPv2',
    mass1=20,
    mass2=20,
    spin1x=0,
    spin1y=0,
    spin1z=0,
    spin2x=0,
    spin2y=0,
    spin2z=0,
    distance=500,
    inclination=,
    coa_phase=,
    f_lower=20,
    f_ref=10,
    delta_t=1/fs
)

# signal = Detector(ifo).project_wave(
#     hp,
#     hc,
#     ra=,
#     dec=,
#     polarization=,
# )

# %%
hp.plot()
hc.plot()
